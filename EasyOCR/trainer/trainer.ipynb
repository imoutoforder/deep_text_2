# %% [markdown]
# import os
# import torch.backends.cudnn as cudnn
# import yaml
# from train import train
# from utils import AttrDict
# import pandas as pd

# %%
cudnn.benchmark = True
cudnn.deterministic = False

# %%
def get_config(file_path):
    with open(file_path, 'r') as stream:
        opt = yaml.safe_load(stream)
    opt = AttrDict(opt)
    print(opt['train_data'])
    print(opt['select_data'])
    if opt.lang_char == 'None':
        characters = ''
        for data in opt['select_data'].split('-'):
            csv_path = os.path.join(opt['train_data'], data, 'train_data','labels.csv')
            df = pd.read_csv(csv_path, sep='^([^,]+),', engine='python', usecols=['filename', 'words'], keep_default_na=False)
            all_char = ''.join(df['words'])
            characters += ''.join(set(all_char))
        characters = sorted(set(characters))
        opt.character= ''.join(characters)
    else:
        opt.character = opt.number + opt.symbol + opt.lang_char
    os.makedirs(f'./saved_models/{opt.experiment_name}', exist_ok=True)
    return opt

# %%
opt = get_config("config_files/fa_filtered_config.yaml")
opt.character
# Out:
# all_data
# fa_train_filtered
# 'ﭖﭗﭘﭙﭺﭻﭼﭽﮊﮋﮎﮏﮐﮑﮒﮓﮔﮕﯼﯽﯾﯿﷲﺀﺁﺂﺃﺄﺅﺆﺇﺋﺌﺍﺎﺏﺐﺑﺒﺓﺔﺕﺖﺗﺘﺙﺚﺛﺜﺝﺞﺟﺠﺡﺢﺣﺤﺥﺦﺧﺨﺩﺪﺫﺬﺭﺮﺯﺰﺱﺲﺳﺴﺵﺶﺷﺸﺹﺺﺻﺼﺽﺾﺿﻀﻁﻂﻃﻄﻅﻆﻇﻈﻉﻊﻋﻌﻍﻎﻏﻐﻑﻒﻓﻔﻕﻖﻗﻘﻙﻚﻛﻜﻝﻞﻟﻠﻡﻢﻣﻤﻥﻦﻧﻨﻩﻪﻫﻬﻭﻮﻯﻰﻱﻲﻳﻴﻷﻹﻻﻼ'

# %%
opt = get_config("config_files/fa_filtered_config.yaml")
train(opt, amp=False)
# Out:
# all_data
# fa_train_filtered
# Filtering the images containing characters which are not in opt.character
# Filtering the images whose label is longer than opt.batch_max_length
# --------------------------------------------------------------------------------
# dataset_root: all_data
# opt.select_data: ['fa_train_filtered']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    all_data	 dataset: fa_train_filtered
# all_data/fa_train_filtered/train_data
# 20000 ?>???????????????????
# sub-directory:	/fa_train_filtered/train_data	 num samples: 20000
# num total samples of fa_train_filtered: 20000 x 1.0 (total_data_usage_ratio) = 20000
# num samples of fa_train_filtered per batch: 32 x 1.0 (batch_ratio) = 32
# --------------------------------------------------------------------------------
# Total_batch_size: 32 = 32
# --------------------------------------------------------------------------------
# dataset_root:    all_data/fa_val	 dataset: /
# all_data/fa_val/
# 2000 ?>???????????????????
# sub-directory:	/.	 num samples: 2000
# --------------------------------------------------------------------------------
# No Transformation module specified
# model input parameters 45 120 20 3 256 256 142 34 None VGG BiLSTM CTC
# Model:
# DataParallel(
#   (module): Model(
#     (FeatureExtraction): VGG_FeatureExtractor(
#       (ConvNet): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): ReLU(inplace=True)
#         (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (7): ReLU(inplace=True)
#         (8): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (9): ReLU(inplace=True)
#         (10): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (11): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (16): ReLU(inplace=True)
#         (17): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (18): Conv2d(256, 256, kernel_size=(2, 2), stride=(1, 1))
#         (19): ReLU(inplace=True)
#       )
#     )
#     (AdaptiveAvgPool): AdaptiveAvgPool2d(output_size=(None, 1))
#     (SequenceModeling): Sequential(
#       (0): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#       (1): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#     )
#     (Prediction): Linear(in_features=256, out_features=142, bias=True)
#   )
# )
# Modules, Parameters
# module.FeatureExtraction.ConvNet.0.weight 864
# module.FeatureExtraction.ConvNet.0.bias 32
# module.FeatureExtraction.ConvNet.3.weight 18432
# module.FeatureExtraction.ConvNet.3.bias 64
# module.FeatureExtraction.ConvNet.6.weight 73728
# module.FeatureExtraction.ConvNet.6.bias 128
# module.FeatureExtraction.ConvNet.8.weight 147456
# module.FeatureExtraction.ConvNet.8.bias 128
# module.FeatureExtraction.ConvNet.11.weight 294912
# module.FeatureExtraction.ConvNet.12.weight 256
# module.FeatureExtraction.ConvNet.12.bias 256
# module.FeatureExtraction.ConvNet.14.weight 589824
# module.FeatureExtraction.ConvNet.15.weight 256
# module.FeatureExtraction.ConvNet.15.bias 256
# module.FeatureExtraction.ConvNet.18.weight 262144
# module.FeatureExtraction.ConvNet.18.bias 256
# module.SequenceModeling.0.rnn.weight_ih_l0 262144
# module.SequenceModeling.0.rnn.weight_hh_l0 262144
# module.SequenceModeling.0.rnn.bias_ih_l0 1024
# module.SequenceModeling.0.rnn.bias_hh_l0 1024
# module.SequenceModeling.0.rnn.weight_ih_l0_reverse 262144
# module.SequenceModeling.0.rnn.weight_hh_l0_reverse 262144
# module.SequenceModeling.0.rnn.bias_ih_l0_reverse 1024
# module.SequenceModeling.0.rnn.bias_hh_l0_reverse 1024
# module.SequenceModeling.0.linear.weight 131072
# module.SequenceModeling.0.linear.bias 256
# module.SequenceModeling.1.rnn.weight_ih_l0 262144
# module.SequenceModeling.1.rnn.weight_hh_l0 262144
# module.SequenceModeling.1.rnn.bias_ih_l0 1024
# module.SequenceModeling.1.rnn.bias_hh_l0 1024
# module.SequenceModeling.1.rnn.weight_ih_l0_reverse 262144
# module.SequenceModeling.1.rnn.weight_hh_l0_reverse 262144
# module.SequenceModeling.1.rnn.bias_ih_l0_reverse 1024
# module.SequenceModeling.1.rnn.bias_hh_l0_reverse 1024
# module.SequenceModeling.1.linear.weight 131072
# module.SequenceModeling.1.linear.bias 256
# module.Prediction.weight 36352
# module.Prediction.bias 142
# Total Trainable Params: 3793486
# Trainable params num :  3793486
# Optimizer:
# Adadelta (
# Parameter Group 0
#     eps: 1e-08
#     lr: 1.0
#     rho: 0.95
#     weight_decay: 0
# )
# ------------ Options -------------
# number: ۱۲۳۴۵۶۷۸۹۰
# symbol: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~ €
# lang_char: None
# experiment_name: fa_filtered
# train_data: all_data
# valid_data: all_data/fa_val
# manualSeed: 1111
# workers: 6
# batch_size: 32
# num_iter: 100
# valInterval: 5
# saved_model:
# FT: False
# optim: False
# lr: 1.0
# beta1: 0.9
# rho: 0.95
# eps: 1e-08
# grad_clip: 5
# select_data: ['fa_train_filtered']
# batch_ratio: ['1']
# total_data_usage_ratio: 1.0
# batch_max_length: 34
# imgH: 45
# imgW: 120
# rgb: True
# contrast_adjust: 0.0
# sensitive: True
# PAD: True
# data_filtering_off: False
# Transformation: None
# FeatureExtraction: VGG
# SequenceModeling: BiLSTM
# Prediction: CTC
# num_fiducial: 20
# input_channel: 3
# output_channel: 256
# hidden_size: 256
# decode: greedy
# new_prediction: False
# freeze_FeatureFxtraction: False
# freeze_SequenceModeling: False
# character: ﭖﭗﭘﭙﭺﭻﭼﭽﮊﮋﮎﮏﮐﮑﮒﮓﮔﮕﯼﯽﯾﯿﷲﺀﺁﺂﺃﺄﺅﺆﺇﺋﺌﺍﺎﺏﺐﺑﺒﺓﺔﺕﺖﺗﺘﺙﺚﺛﺜﺝﺞﺟﺠﺡﺢﺣﺤﺥﺦﺧﺨﺩﺪﺫﺬﺭﺮﺯﺰﺱﺲﺳﺴﺵﺶﺷﺸﺹﺺﺻﺼﺽﺾﺿﻀﻁﻂﻃﻄﻅﻆﻇﻈﻉﻊﻋﻌﻍﻎﻏﻐﻑﻒﻓﻔﻕﻖﻗﻘﻙﻚﻛﻜﻝﻞﻟﻠﻡﻢﻣﻤﻥﻦﻧﻨﻩﻪﻫﻬﻭﻮﻯﻰﻱﻲﻳﻴﻷﻹﻻﻼ
# num_class: 142
# ---------------------------------------
# /home/yousef/anaconda3/envs/easy/lib/python3.8/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# /home/yousef/anaconda3/envs/easy/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# training time:  6.078711748123169
# [5/100] Train loss: 11.93793, Valid loss: 9.36095, Elapsed_time: 6.08189
# Current_accuracy : 0.000, Current_norm_ED  : 0.0000
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0000
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﻣﻌﺎﻣﻼﺕ                    |                           | 0.0000	False
# ﺧﺸﺨﺎﺵ                     |                           | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  23.117878675460815
# training time:  3.125652551651001
# [10/100] Train loss: 7.18259, Valid loss: 5.16462, Elapsed_time: 32.32594
# Current_accuracy : 0.000, Current_norm_ED  : 0.0000
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0000
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﺳﺒﻌﯿﺖ                     |                           | 0.0990	False
# ﺟﻌﺪ                       |                           | 0.1058	False
# --------------------------------------------------------------------------------
# validation time:  23.216266870498657
# training time:  3.393754720687866
# [15/100] Train loss: 5.50938, Valid loss: 6.12675, Elapsed_time: 58.93673
# Current_accuracy : 0.000, Current_norm_ED  : 0.0000
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0000
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﻗﺮﯾﺤﻪ                     |                           | 0.0000	False
# ﭘﺪﺭ                       |                           | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  21.430307149887085
# training time:  3.4364373683929443
# [20/100] Train loss: 5.52934, Valid loss: 4.90325, Elapsed_time: 83.80365
# Current_accuracy : 0.000, Current_norm_ED  : 0.0000
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0000
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﻟﻤﺎ                       |                           | 0.0495	False
# ﻧﯿﺎﺑﺖ                     |                           | 0.0854	False
# --------------------------------------------------------------------------------
# validation time:  23.0955970287323
# training time:  3.1849429607391357
# [25/100] Train loss: 5.00083, Valid loss: 5.38696, Elapsed_time: 110.08439
# Current_accuracy : 0.000, Current_norm_ED  : 0.0082
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0082
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﺍﻣﭙﺮﯾﺎﻟﯿﺴﺖ                |                           | 0.0000	False
# ﻣﻨﺼﻪ                      |                           | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  21.987221240997314
# training time:  3.345338821411133
# [30/100] Train loss: 4.99161, Valid loss: 4.62275, Elapsed_time: 135.41711
# Current_accuracy : 0.000, Current_norm_ED  : 0.0000
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0082
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﻗﺮﺍﺑﺖ                     |                           | 0.0334	False
# ﮐﺎﺱ                       |                           | 0.0126	False
# --------------------------------------------------------------------------------
# validation time:  23.438833713531494
# training time:  3.4651694297790527
# [35/100] Train loss: 4.75815, Valid loss: 4.89101, Elapsed_time: 162.32176
# Current_accuracy : 0.000, Current_norm_ED  : 0.0176
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0176
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﻣﺘﺠﺎﻭﺯ                    | ﯽ                         | 0.0000	False
# ﻭﻗﺘﯿﮑﻪ                    | ﯽ                         | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  21.866305828094482
# training time:  3.1115102767944336
# [40/100] Train loss: 4.56755, Valid loss: 4.51708, Elapsed_time: 187.30001
# Current_accuracy : 0.000, Current_norm_ED  : 0.0066
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0176
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﭼﭽﻮﻝ                      | ﯽ                         | 0.0079	False
# ﺍﺩﻫﻢ                      | ﯽ                         | 0.0076	False
# --------------------------------------------------------------------------------
# validation time:  20.871866703033447
# training time:  3.3781237602233887
# [45/100] Train loss: 4.49976, Valid loss: 4.71439, Elapsed_time: 211.55044
# Current_accuracy : 0.050, Current_norm_ED  : 0.0653
# Best_accuracy    : 0.050, Best_norm_ED     : 0.0653
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﺧﺮﺩﻟﯽ                     | ﻣﯽ                        | 0.0000	False
# ﺛﻐﻮﺭ                      | ﻣﯽ                        | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  22.015307188034058
# training time:  3.087759494781494
# [50/100] Train loss: 4.47264, Valid loss: 4.41121, Elapsed_time: 236.65442
# Current_accuracy : 0.050, Current_norm_ED  : 0.0373
# Best_accuracy    : 0.050, Best_norm_ED     : 0.0653
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﻧﺎﻫﻤﺎﻧﻨﺪ                  | ﻪ                         | 0.0078	False
# ﺳﺘﻮﺍﻥ                     | ﻣﯽ                        | 0.0065	False
# --------------------------------------------------------------------------------
# validation time:  20.883058071136475
# training time:  3.139157295227051
# [55/100] Train loss: 4.38695, Valid loss: 4.45747, Elapsed_time: 260.67682
# Current_accuracy : 0.000, Current_norm_ED  : 0.0652
# Best_accuracy    : 0.050, Best_norm_ED     : 0.0653
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﺩﺭﻭﯾﺸﯽ                    | ﻣﯽ                        | 0.0000	False
# ﺑﺰﺭﮔﻮﺍﺭﺍﻧﻪ                | ﻣﻪ                        | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  22.609657049179077
# training time:  3.099238872528076
# [60/100] Train loss: 4.45255, Valid loss: 4.31205, Elapsed_time: 286.38590
# Current_accuracy : 0.000, Current_norm_ED  : 0.0191
# Best_accuracy    : 0.050, Best_norm_ED     : 0.0653
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﻣﮑﺎﻟﻤﻪ                    | ﻪ                         | 0.0039	False
# ﺭﺍﯼ                       | ﻪ                         | 0.0056	False
# --------------------------------------------------------------------------------
# validation time:  21.193602323532104
# training time:  3.093780994415283
# [65/100] Train loss: 4.32071, Valid loss: 4.36697, Elapsed_time: 310.67394
# Current_accuracy : 0.000, Current_norm_ED  : 0.0849
# Best_accuracy    : 0.050, Best_norm_ED     : 0.0849
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﺳﺎﺣﺮﻩ                     | ﻣﻪ                        | 0.0000	False
# ﺗﻌﺮﯾﮏ                     | ﻣﺎﻪ                       | 0.0001	False
# --------------------------------------------------------------------------------
# validation time:  21.55065679550171
# training time:  2.737454414367676
# [70/100] Train loss: 4.15433, Valid loss: 4.19731, Elapsed_time: 334.96224
# Current_accuracy : 0.050, Current_norm_ED  : 0.0630
# Best_accuracy    : 0.050, Best_norm_ED     : 0.0849
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﭼﺮﺕ                       | ﻣﯽ                        | 0.0066	False
# ﺗﻮﺍﻥ                      | ﻣﯽ                        | 0.0065	False
# --------------------------------------------------------------------------------
# validation time:  20.90627956390381
# training time:  2.9411613941192627
# [75/100] Train loss: 4.21824, Valid loss: 4.23935, Elapsed_time: 358.81053
# Current_accuracy : 0.000, Current_norm_ED  : 0.1076
# Best_accuracy    : 0.050, Best_norm_ED     : 0.1076
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﺑﺪﺍﻫﺖ                     | ﻣﺎﻪ                       | 0.0001	False
# ﭼﺴﺒﯿﺪﮔﯽ                   | ﻣﺎﻪ                       | 0.0001	False
# --------------------------------------------------------------------------------
# validation time:  22.276461601257324
# training time:  3.085965394973755
# [80/100] Train loss: 4.30210, Valid loss: 4.18292, Elapsed_time: 384.17547
# Current_accuracy : 0.000, Current_norm_ED  : 0.0548
# Best_accuracy    : 0.050, Best_norm_ED     : 0.1076
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﺯﺭﻕ                       | ﺑﻪ                        | 0.0026	False
# ﺯﺍﯾﺶ                      | ﺑﻪ                        | 0.0019	False
# --------------------------------------------------------------------------------
# validation time:  24.063364028930664
# training time:  2.4510557651519775
# [85/100] Train loss: 4.06591, Valid loss: 4.09030, Elapsed_time: 410.69024
# Current_accuracy : 0.000, Current_norm_ED  : 0.0627
# Best_accuracy    : 0.050, Best_norm_ED     : 0.1076
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﺳﺮﺣﺪﺩﺍﺭ                   | ﺗﯿﯽ                       | 0.0001	False
# ﻣﻔﺴﺪ                      | ﺗﯽ                        | 0.0001	False
# --------------------------------------------------------------------------------
# validation time:  25.162052392959595
# training time:  3.1131017208099365
# [90/100] Train loss: 4.04544, Valid loss: 4.05546, Elapsed_time: 438.96612
# Current_accuracy : 0.000, Current_norm_ED  : 0.0583
# Best_accuracy    : 0.050, Best_norm_ED     : 0.1076
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﺳﻔﯿﻪ                      | ﻣﻥ                        | 0.0010	False
# ﺑﻬﺎﺑﺎﺯﺍﺭ                  | ﻣﻥ                        | 0.0007	False
# --------------------------------------------------------------------------------
# validation time:  21.38722252845764
# training time:  3.085756301879883
# [95/100] Train loss: 4.26169, Valid loss: 4.03192, Elapsed_time: 463.43932
# Current_accuracy : 0.000, Current_norm_ED  : 0.0532
# Best_accuracy    : 0.050, Best_norm_ED     : 0.1076
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﺷﮑﺎﮎ                      | ﻣﯼ                        | 0.0009	False
# ﻧﻈﻤﯿﻪ                     | ﻣﯼ                        | 0.0006	False
# --------------------------------------------------------------------------------
# validation time:  22.726736783981323
# training time:  3.1041016578674316
# [100/100] Train loss: 4.11668, Valid loss: 4.11334, Elapsed_time: 489.27035
# Current_accuracy : 0.000, Current_norm_ED  : 0.0690
# Best_accuracy    : 0.050, Best_norm_ED     : 0.1076
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﺑﻨﺎﺩﺭ                     | ﻣﺎﯼ                       | 0.0000	False
# ﻫﺮﺏ                       | ﻣﯼ                        | 0.0001	False
# --------------------------------------------------------------------------------
# validation time:  22.7798969745636
# end the training
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/yousef/anaconda3/envs/easy/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3449: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
