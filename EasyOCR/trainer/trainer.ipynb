# %%
import os
import torch.backends.cudnn as cudnn
import yaml
from train import train
from utils import AttrDict
import pandas as pd

# %%
cudnn.benchmark = True
cudnn.deterministic = False

# %%
def get_config(file_path):
    with open(file_path, 'r') as stream:
        opt = yaml.safe_load(stream)
    opt = AttrDict(opt)
    print(opt['train_data'])
    print(opt['select_data'])
    if opt.lang_char == 'None':
        characters = ''
        for data in opt['select_data'].split('-'):
            csv_path = os.path.join(opt['train_data'], data, 'train_data','labels.csv')
            df = pd.read_csv(csv_path, sep='^([^,]+),', engine='python', usecols=['filename', 'words'], keep_default_na=False)
            all_char = ''.join(df['words'])
            characters += ''.join(set(all_char))
        characters = sorted(set(characters))
        opt.character= ''.join(characters)
    else:
        opt.character = opt.number + opt.symbol + opt.lang_char
    os.makedirs(f'./saved_models/{opt.experiment_name}', exist_ok=True)
    return opt

# %%
opt = get_config("config_files/fa_filtered_config.yaml")
opt.character
# Out:
# all_data
# fa_train_filtered
# 'ﭖﭗﭘﭙﭺﭻﭼﭽﮊﮋﮎﮏﮐﮑﮒﮓﮔﮕﯼﯽﯾﯿﷲﺀﺁﺂﺃﺄﺅﺆﺇﺋﺌﺍﺎﺏﺐﺑﺒﺓﺔﺕﺖﺗﺘﺙﺚﺛﺜﺝﺞﺟﺠﺡﺢﺣﺤﺥﺦﺧﺨﺩﺪﺫﺬﺭﺮﺯﺰﺱﺲﺳﺴﺵﺶﺷﺸﺹﺺﺻﺼﺽﺾﺿﻀﻁﻂﻃﻄﻅﻆﻇﻈﻉﻊﻋﻌﻍﻎﻏﻐﻑﻒﻓﻔﻕﻖﻗﻘﻙﻚﻛﻜﻝﻞﻟﻠﻡﻢﻣﻤﻥﻦﻧﻨﻩﻪﻫﻬﻭﻮﻯﻰﻱﻲﻳﻴﻷﻹﻻﻼ'

# %%
opt = get_config("config_files/fa_filtered_config.yaml")
train(opt, amp=False)
# Out:
# all_data
# fa_train_filtered
# Filtering the images containing characters which are not in opt.character
# Filtering the images whose label is longer than opt.batch_max_length
# --------------------------------------------------------------------------------
# dataset_root: all_data
# opt.select_data: ['fa_train_filtered']
# opt.batch_ratio: ['1']
# --------------------------------------------------------------------------------
# dataset_root:    all_data	 dataset: fa_train_filtered
# all_data/fa_train_filtered/train_data
# sub-directory:	/fa_train_filtered/train_data	 num samples: 20000
# num total samples of fa_train_filtered: 20000 x 1.0 (total_data_usage_ratio) = 20000
# num samples of fa_train_filtered per batch: 32 x 1.0 (batch_ratio) = 32
# --------------------------------------------------------------------------------
# Total_batch_size: 32 = 32
# --------------------------------------------------------------------------------
# dataset_root:    all_data/fa_val	 dataset: /
# all_data/fa_val/
# sub-directory:	/.	 num samples: 2000
# --------------------------------------------------------------------------------
# No Transformation module specified
# model input parameters 45 120 20 3 256 256 142 34 None VGG BiLSTM CTC
# Model:
# DataParallel(
#   (module): Model(
#     (FeatureExtraction): VGG_FeatureExtractor(
#       (ConvNet): Sequential(
#         (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): ReLU(inplace=True)
#         (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): ReLU(inplace=True)
#         (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (7): ReLU(inplace=True)
#         (8): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (9): ReLU(inplace=True)
#         (10): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (11): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (12): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (13): ReLU(inplace=True)
#         (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (16): ReLU(inplace=True)
#         (17): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (18): Conv2d(256, 256, kernel_size=(2, 2), stride=(1, 1))
#         (19): ReLU(inplace=True)
#       )
#     )
#     (AdaptiveAvgPool): AdaptiveAvgPool2d(output_size=(None, 1))
#     (SequenceModeling): Sequential(
#       (0): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#       (1): BidirectionalLSTM(
#         (rnn): LSTM(256, 256, batch_first=True, bidirectional=True)
#         (linear): Linear(in_features=512, out_features=256, bias=True)
#       )
#     )
#     (Prediction): Linear(in_features=256, out_features=142, bias=True)
#   )
# )
# Modules, Parameters
# module.FeatureExtraction.ConvNet.0.weight 864
# module.FeatureExtraction.ConvNet.0.bias 32
# module.FeatureExtraction.ConvNet.3.weight 18432
# module.FeatureExtraction.ConvNet.3.bias 64
# module.FeatureExtraction.ConvNet.6.weight 73728
# module.FeatureExtraction.ConvNet.6.bias 128
# module.FeatureExtraction.ConvNet.8.weight 147456
# module.FeatureExtraction.ConvNet.8.bias 128
# module.FeatureExtraction.ConvNet.11.weight 294912
# module.FeatureExtraction.ConvNet.12.weight 256
# module.FeatureExtraction.ConvNet.12.bias 256
# module.FeatureExtraction.ConvNet.14.weight 589824
# module.FeatureExtraction.ConvNet.15.weight 256
# module.FeatureExtraction.ConvNet.15.bias 256
# module.FeatureExtraction.ConvNet.18.weight 262144
# module.FeatureExtraction.ConvNet.18.bias 256
# module.SequenceModeling.0.rnn.weight_ih_l0 262144
# module.SequenceModeling.0.rnn.weight_hh_l0 262144
# module.SequenceModeling.0.rnn.bias_ih_l0 1024
# module.SequenceModeling.0.rnn.bias_hh_l0 1024
# module.SequenceModeling.0.rnn.weight_ih_l0_reverse 262144
# module.SequenceModeling.0.rnn.weight_hh_l0_reverse 262144
# module.SequenceModeling.0.rnn.bias_ih_l0_reverse 1024
# module.SequenceModeling.0.rnn.bias_hh_l0_reverse 1024
# module.SequenceModeling.0.linear.weight 131072
# module.SequenceModeling.0.linear.bias 256
# module.SequenceModeling.1.rnn.weight_ih_l0 262144
# module.SequenceModeling.1.rnn.weight_hh_l0 262144
# module.SequenceModeling.1.rnn.bias_ih_l0 1024
# module.SequenceModeling.1.rnn.bias_hh_l0 1024
# module.SequenceModeling.1.rnn.weight_ih_l0_reverse 262144
# module.SequenceModeling.1.rnn.weight_hh_l0_reverse 262144
# module.SequenceModeling.1.rnn.bias_ih_l0_reverse 1024
# module.SequenceModeling.1.rnn.bias_hh_l0_reverse 1024
# module.SequenceModeling.1.linear.weight 131072
# module.SequenceModeling.1.linear.bias 256
# module.Prediction.weight 36352
# module.Prediction.bias 142
# Total Trainable Params: 3793486
# Trainable params num :  3793486
# Optimizer:
# Adadelta (
# Parameter Group 0
#     eps: 1e-08
#     lr: 1.0
#     rho: 0.95
#     weight_decay: 0
# )
# ------------ Options -------------
# number: ۱۲۳۴۵۶۷۸۹۰
# symbol: !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~ €
# lang_char: None
# experiment_name: fa_filtered
# train_data: all_data
# valid_data: all_data/fa_val
# manualSeed: 1111
# workers: 6
# batch_size: 32
# num_iter: 80
# valInterval: 5
# saved_model:
# FT: False
# optim: False
# lr: 1.0
# beta1: 0.9
# rho: 0.95
# eps: 1e-08
# grad_clip: 5
# select_data: ['fa_train_filtered']
# batch_ratio: ['1']
# total_data_usage_ratio: 1.0
# batch_max_length: 34
# imgH: 45
# imgW: 120
# rgb: True
# contrast_adjust: 0.0
# sensitive: True
# PAD: True
# data_filtering_off: False
# Transformation: None
# FeatureExtraction: VGG
# SequenceModeling: BiLSTM
# Prediction: CTC
# num_fiducial: 20
# input_channel: 3
# output_channel: 256
# hidden_size: 256
# decode: greedy
# new_prediction: False
# freeze_FeatureFxtraction: False
# freeze_SequenceModeling: False
# character: ﭖﭗﭘﭙﭺﭻﭼﭽﮊﮋﮎﮏﮐﮑﮒﮓﮔﮕﯼﯽﯾﯿﷲﺀﺁﺂﺃﺄﺅﺆﺇﺋﺌﺍﺎﺏﺐﺑﺒﺓﺔﺕﺖﺗﺘﺙﺚﺛﺜﺝﺞﺟﺠﺡﺢﺣﺤﺥﺦﺧﺨﺩﺪﺫﺬﺭﺮﺯﺰﺱﺲﺳﺴﺵﺶﺷﺸﺹﺺﺻﺼﺽﺾﺿﻀﻁﻂﻃﻄﻅﻆﻇﻈﻉﻊﻋﻌﻍﻎﻏﻐﻑﻒﻓﻔﻕﻖﻗﻘﻙﻚﻛﻜﻝﻞﻟﻠﻡﻢﻣﻤﻥﻦﻧﻨﻩﻪﻫﻬﻭﻮﻯﻰﻱﻲﻳﻴﻷﻹﻻﻼ
# num_class: 142
# ---------------------------------------
# /home/yousef/anaconda3/envs/easy/lib/python3.8/site-packages/torch/cuda/amp/grad_scaler.py:115: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn("torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.")
# /home/yousef/anaconda3/envs/easy/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# training time:  5.79464054107666
# [5/80] Train loss: 11.32379, Valid loss: 13.73308, Elapsed_time: 5.80075
# Current_accuracy : 0.000, Current_norm_ED  : 0.0008
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0008
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﻣﺼﺮﻑ                      |                           | 0.0000	False
# ﭼﻨﯿﻦ                      |                           | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  23.66562581062317
# training time:  2.907871961593628
# [10/80] Train loss: 7.33129, Valid loss: 7.94395, Elapsed_time: 32.37478
# Current_accuracy : 0.000, Current_norm_ED  : 0.0000
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0008
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﻧﻔﺎﺫ                      |                           | 0.0000	False
# ﻫﺮﺏ                       |                           | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  22.881320476531982
# training time:  2.747697353363037
# [15/80] Train loss: 6.24388, Valid loss: 4.78664, Elapsed_time: 58.00400
# Current_accuracy : 0.000, Current_norm_ED  : 0.0000
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0008
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﻗﻮﯾﻢ                      |                           | 0.0215	False
# ﮔﻨﮕﯽ                      |                           | 0.0149	False
# --------------------------------------------------------------------------------
# validation time:  25.02520728111267
# training time:  4.436378717422485
# [20/80] Train loss: 5.34516, Valid loss: 5.70789, Elapsed_time: 87.46579
# Current_accuracy : 0.000, Current_norm_ED  : 0.0000
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0008
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﺻﯿﻘﻠﯽ                     |                           | 0.0000	False
# ﺿﺮﯾﺢ                      |                           | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  29.76585817337036
# training time:  4.112253904342651
# [25/80] Train loss: 5.29179, Valid loss: 4.61157, Elapsed_time: 121.34509
# Current_accuracy : 0.000, Current_norm_ED  : 0.0000
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0008
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﺧﺮﺍﺷﺎﻧﺪﻥ                  |                           | 0.0218	False
# ﭼﯿﺮﻩ                      |                           | 0.0228	False
# --------------------------------------------------------------------------------
# validation time:  28.324532747268677
# training time:  3.1370291709899902
# [30/80] Train loss: 4.87514, Valid loss: 5.10367, Elapsed_time: 152.80775
# Current_accuracy : 0.000, Current_norm_ED  : 0.0431
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0431
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﻗﺮﺍﺳﻮﺭﺍﻥ                  | ﻣ                         | 0.0000	False
# ﺩﻫﺮ                       | ﻣ                         | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  33.1068172454834
# training time:  6.5087738037109375
# [35/80] Train loss: 4.69869, Valid loss: 4.52452, Elapsed_time: 192.42386
# Current_accuracy : 0.000, Current_norm_ED  : 0.0000
# Best_accuracy    : 0.000, Best_norm_ED     : 0.0431
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﻣﺸﯿﺖ                      |                           | 0.0154	False
# ﺗﻮﺍﻥ                      |                           | 0.0206	False
# --------------------------------------------------------------------------------
# validation time:  32.85809254646301
# training time:  3.8574318885803223
# [40/80] Train loss: 4.56614, Valid loss: 4.69955, Elapsed_time: 229.13956
# Current_accuracy : 0.050, Current_norm_ED  : 0.0629
# Best_accuracy    : 0.050, Best_norm_ED     : 0.0629
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﺧﻤﺶ                       | ﻣﯽ                        | 0.0000	False
# ﻣﺮﺑﻮﺏ                     | ﻣﯽ                        | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  29.216857433319092
# training time:  3.821964740753174
# [45/80] Train loss: 4.49363, Valid loss: 4.41807, Elapsed_time: 262.17889
# Current_accuracy : 0.000, Current_norm_ED  : 0.0352
# Best_accuracy    : 0.050, Best_norm_ED     : 0.0629
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﺑﻨﺎﺩﺭ                     | ﻣ                         | 0.0049	False
# ﺑﯿﮓ                       | ﻣ                         | 0.0043	False
# --------------------------------------------------------------------------------
# validation time:  30.1069438457489
# training time:  3.5995798110961914
# [50/80] Train loss: 4.40778, Valid loss: 4.29884, Elapsed_time: 295.88565
# Current_accuracy : 0.050, Current_norm_ED  : 0.0647
# Best_accuracy    : 0.050, Best_norm_ED     : 0.0647
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﺩﺍﺭﺍﻟﺸﻔﺎﺀ                 | ﻣﯽ                        | 0.0001	False
# ﺑﻄﺶ                       | ﻣﯽ                        | 0.0001	False
# --------------------------------------------------------------------------------
# validation time:  29.9196298122406
# training time:  3.9241790771484375
# [55/80] Train loss: 4.22449, Valid loss: 4.29400, Elapsed_time: 329.72966
# Current_accuracy : 0.000, Current_norm_ED  : 0.0395
# Best_accuracy    : 0.050, Best_norm_ED     : 0.0647
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﺗﺪﺭﯾﺠﺘﺪﺭﯾﺲ                | ﺍ                         | 0.0018	False
# ﻫﻮﺍﺧﻮﺭﯼ                   | ﺍ                         | 0.0026	False
# --------------------------------------------------------------------------------
# validation time:  33.015312910079956
# training time:  4.95858097076416
# [60/80] Train loss: 4.26737, Valid loss: 4.25489, Elapsed_time: 367.70419
# Current_accuracy : 0.000, Current_norm_ED  : 0.0915
# Best_accuracy    : 0.050, Best_norm_ED     : 0.0915
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﺑﯿﺎﺑﻨﺪ                    | ﻣﺎﯽ                       | 0.0000	False
# ﺑﺎﺭﻭﺑﻨﻪ                   | ﻣﺎﯽ                       | 0.0000	False
# --------------------------------------------------------------------------------
# validation time:  33.189270973205566
# training time:  4.3171350955963135
# [65/80] Train loss: 4.21357, Valid loss: 4.25979, Elapsed_time: 405.21109
# Current_accuracy : 0.000, Current_norm_ED  : 0.0356
# Best_accuracy    : 0.050, Best_norm_ED     : 0.0915
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﻋﻨﻮﺍﻥ                     | ﺗﯽ                        | 0.0030	False
# ﮐﺮ                        | ﺗﯽ                        | 0.0036	False
# --------------------------------------------------------------------------------
# validation time:  31.29604148864746
# training time:  4.20903468132019
# [70/80] Train loss: 4.11250, Valid loss: 4.16407, Elapsed_time: 440.71636
# Current_accuracy : 0.000, Current_norm_ED  : 0.1219
# Best_accuracy    : 0.050, Best_norm_ED     : 0.1219
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﺑﺎﺣﺸﻤﺖ                    | ﻣﺎﻪ                       | 0.0001	False
# ﺗﻬﻠﮑﻪ                     | ﻣﺎﯽ                       | 0.0001	False
# --------------------------------------------------------------------------------
# validation time:  32.36433720588684
# training time:  4.296374797821045
# [75/80] Train loss: 4.04649, Valid loss: 4.13933, Elapsed_time: 477.37831
# Current_accuracy : 0.000, Current_norm_ED  : 0.0598
# Best_accuracy    : 0.050, Best_norm_ED     : 0.1219
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﺑﺎﮊ                       | ﻣ                         | 0.0023	False
# ﺭﻫﻦ                       | ﻣ                         | 0.0016	False
# --------------------------------------------------------------------------------
# validation time:  31.47261095046997
# training time:  3.9384522438049316
# [80/80] Train loss: 4.04578, Valid loss: 4.08273, Elapsed_time: 512.78957
# Current_accuracy : 0.000, Current_norm_ED  : 0.0876
# Best_accuracy    : 0.050, Best_norm_ED     : 0.1219
# --------------------------------------------------------------------------------
# Ground Truth              | Prediction                | Confidence Score & T/F
# --------------------------------------------------------------------------------
# ﻫﺎﻱ                       | ﺗﺎﻪ                       | 0.0003	False
# ﻫﺎﻟﻪ                      | ﺗﺎﻪ                       | 0.0002	False
# --------------------------------------------------------------------------------
# validation time:  31.565030336380005
# end the training
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# /home/yousef/anaconda3/envs/easy/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3449: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# %tb
# Out:
# ---------------------------------------------------------------------------
# SystemExit                                Traceback (most recent call last)
# /tmp/ipykernel_3592/2390046661.py in <module>
#       1 opt = get_config("config_files/fa_filtered_config.yaml")
# ----> 2 train(opt, amp=False)
#
# ~/Desktop/ocr/EasyOCR/trainer/train.py in train(opt, show_number, amp)
#     278         if i == opt.num_iter:
#     279             print('end the training')
# --> 280             sys.exit()
#     281         i += 1
#     282
#
# SystemExit:
